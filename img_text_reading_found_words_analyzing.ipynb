# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperGrodecki/image_proccessing/blob/main/kuba_img_text_reading_found_words_analyzing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install pyenchant
# Out:
# Requirement already satisfied: pyenchant in /usr/local/lib/python3.7/dist-packages (3.2.2)

# %%
# !apt install -qq enchant
# Out:
# enchant is already the newest version (1.6.0-11.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !apt-get install myspell-pl
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# myspell-pl is already the newest version (20170707-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import enchant
import pandas as pd
import cv2
import numpy as np
import re
import matplotlib.pyplot as plt      
import pickle
from os import listdir
from os.path import isfile, join
import gc
import sys
import pickle
import string
import difflib

# %%
d = enchant.Dict('PL')

# %%
text=pd.read_csv('drive/MyDrive/kuba/odczyt_0_85.csv',index_col=0)

# %%
text.tail(20)
# Out:
#                                                        0
# 13667  nowymi i prasą paxowską; Machowski - nt. kolpo...
# 13668  PAX, W dyskusji zebrało głos 15 osób w tym Rei...
# 13669  wicz, Dębrowski, Podsumowania dyskusji dokonał...
# 13670  W rererciech, podsumowaniu orcz dyskusji na uwagę
# 13671                                         zasługują:
# 13672      tcena kciolicyzmu w Polsce . Stwierdzano, że:
# 13673      ccena kciolicyzmu w Polsce , Stwierdzano, że:
# 13674  część biskupów i duchowieńsiwa wyraża niezadow...
# 13675  z zarysowsujęcych się możliwości normalizacji ...
# 13676                         między Polską a Watykanem;
# 13677  w związku z reformą oświaty i wychowenia oraz ...
# 13678  dostosowania katechizacji do nowych warunków u...
# 13679  się katostrofalny stan nauki religii w punktac...
# 13680  nych oraz brak inicjatyw u księży w zakresie u...
# 13681                              pracy no tym odcinku;
# 13682  w środo /iskach katolików świeckich /"Znak", C...
# 13683  narosta rozkład organizacyjny, spowodowany bra...
# 13684  gramu działania. Świadczy to o bezsensowności ...
# 13685             tzw. trójpolówki katolickiej w Polsce;
# 13686                                           99 z 348

# %%
#check dictionary correction
string_pl=string.ascii_lowercase+'ąśćęó'

file='drive/MyDrive/kuba/odm.txt'


def make_dict(file):
    with open(file, encoding='UTF8') as f:
        lines = f.readlines()
    dict_pl = []
    for line in lines:
        word=line.split()
        dict_pl.append(word)
 
    return [item.replace(',','') for sublist in dict_pl for item in sublist]

dict_pl=make_dict(file)

def check_pl(text):
    return text in dict_pl 

def dicts_pl():
    dicts=[None]*len(string_pl)
    i=0
    for ch in string_pl:
        dicts[i]=[x for x in dict_pl if x[0]==ch ]
        i+=1
    return dicts
        

dicts=dicts_pl()

key=[None]*len(string_pl)
i=0
for ch in string_pl:
        key[i]=ch
        i+=1

def check_string_pl(a):
    result=0
    a=''.join(filter(whitelist.__contains__, a))
    for word in a.split():
       # print(word,' ',check_pl(word))
        result+=int(check_pl_alfabet(word.lower()))
    if len(a.split())>0:
        return result/len(a.split())
    else:
        return 0

def word_correction(a):
    for word in a.split():
        if len(word)>1:
            if check_string_pl(word.lower())<1:
                for i in range(0,len(word)+1):
                    if i==0:
                        for replace in String_pl:
                            word_new=replace+word[1:]
                            if check_pl_alfabet(word_new):
                                print(word_new)
                    else:
                        for replace in String_pl:
                            word_new=word[:i]+replace+word[i+1:]
                            if check_pl_alfabet(word_new):
                                print(word_new)

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
import re

# %%
#text='\sdv\bf#'

# %%
#re.sub(r'\W+', '', text)

# %%
def word_correction(a):
    a=str(a)
    correct=[]
    for word in a.split():
        word=re.sub(r'\W+', '', word)
        if len(word)>1:
            if word.isnumeric():
              continue
            try:
              #print('word',word)
              if int(d.check(word))==1:
                return word
              else:
                #take each letter and
                letter_dict=dicts[ord(word.lower()[0])-97]
                #for each letter change it to 
                for local in letter_dict:
                  score=similar(word.lower(),local)
                  if score>=0.9 and score<1:
                    print('sencence ',a,'word',word,' local ',local,' score ',score)
                #maximum=max([similar(word.lower(),local) for local in letter_dict])
                #print(word,' ',maximum)
                correct.append(maximum)
            except:
              pass
    return np.array(correct)

# %%
def word_correction(a):
    a=str(a)
    print('sentence: ',a)
    correct=[]
    new_sentence=''
    correction=0
    for word in a.split():
        word=re.sub(r'\W+', '', word)
        if len(word)>1:
            if word.isnumeric():
              continue
            try:
              #print('word',word)
              if int(d.check(word))==1:
                #print('correct',word)
                new_sentence+=word+' '
                continue
              else:
                correction=1
                letter_dict=dicts[ord(word.lower()[0])-97]
                #print(len(letter_dict))
                locals={}
                scores=[]
                score_high=0
                for local in letter_dict:
                  score=similar(word.lower(),local)
                  #print(score)
                  if score>=0.8 and score<1:
                    locals[local]=score
                    if score>score_high:
                      #print(score,' ',local)
                      score_high=score

                key_list = list(locals.keys())
                val_list = list(locals.values())
                position = val_list.index(score_high)
                local=key_list[position]
                #print(locals[score_high])
                    
                print(word,' change to ',local,' score ',score_high)
                new_sentence+=local+' '
                #maximum=max([similar(word.lower(),local) for local in letter_dict])
                #print(word,' ',maximum)
                correct.append(maximum)
            except:
              pass
    if correction==1:
      print('final ',new_sentence)    
    return new_sentence

# %%
def word_correction(a):
    a=str(a)
    print('sentence: ',a)
    new_sentence=''
    correction=0
    for word in a.split():
        word=re.sub(r'\W+', '', word)
        if len(word)>1:
            if word.isnumeric():
              continue
            try:
              #print('word',word)
              if int(d.check(word))==1:
                #print('correct',word)
                new_sentence+=word+' '
                continue
              else:
                #print('bad ',word)
                correction=1
                letter_dict=dicts[ord(word.lower()[0])-97]
                local=difflib.get_close_matches(word, letter_dict)
                #print(word,' change to ',local,' score ')
                new_sentence+=local[0]+' '
                #maximum=max([similar(word.lower(),local) for local in letter_dict])
                #print(word,' ',maximum)
            except:
              pass
    if correction==1:
      print('final ',new_sentence)    
    return new_sentence

# %%
word='trwac'
letter_dict=dicts[ord(word.lower()[0])-97]
local=difflib.get_close_matches(word, letter_dict)

# %%
x='trwac dom'
word_correction(x)
# Out:
# sentence:  trwac dom
# bad  trwac
# trwac  change to  ['trwa', 'trwając', 'trwacie']  score
# final  trwa dom
# 'trwa dom '

# %%
text.applymap(lambda x: word_correction(x))
# Out:
# sentence:  drive/MyDrive/kuba/zdjecia/fig1.jpg
# final
# sentence:  Własność
# archiwum
# Aktotwórca
# Tytuł teczki
# Daty skrajne
# jednostki
# archiwalnej
# Stara sygnatura
# Sygnatura
# archiwalna
# final  Własność archiwum aktinotrocha Tytuł teczki Daty skrajne jednostki archiwalnej Stara sygnatura Sygnatura archiwalna
# sentence:  IPN BU 0 639/223
# sentence:  KARTA INFORMACYJNA
# sentence:  Instytut Pamięci Narodowej w Warszawie
# sentence:  Aktotwórca
# final  aktinotrocha
# sentence:  MSW
# sentence:  Tytuł teczki
# sentence:  PAX- materiały dotyczące działalności zrzeszenia
# sentence:  Daty skrajne
# sentence:  jednostki
# sentence:  archiwalnej
# sentence:  IPN BU 0639/223
# sentence:  Sygnatura
# sentence:  archiwalna
# sentence:  drive/MyDrive/kuba/zdjecia/fig10.jpg
# final
# sentence:  Za ałą EZEHO 639/223
# final  Za ałyczą
# sentence:  STRUKTURA I WYKONANIE BUDŻETÓW
# sentence:  KATOLICKICH ORGANIZACJI SPOŁECZNYCH :
# sentence:  "PAX", ChSS, KIK za rok 1971
# final  PAX KIK za rok
# sentence:  STOWARZYSZENIE "PAX"
# sentence:  Realizacja budżetu. za rok 1971:
# sentence:  = 36, 720, 000,7 GŁ.
# sentence:  - działalność statutowa
# sentence:  - pokrycie straty prasy i wydawnictw - 28.680.000." zł.
# sentence:  __..razem;_ 65.400.000, - zł.
# final  zł
# sentence:  — mem. 65.400.000, zł.
# sentence:  Struktura budżetu :
# sentence:  1. Płace / osobowy fundusz płac,
# sentence:  narzuty, bezosobowy fum'usz
# final  narzuty bezosobowy fumu
# sentence:  płac, Fumdusz honorariów /
# final  płac fundusz honorariów
# sentence:  275.000.” zł,
# sentence:  2. Lundusz nagród
# final  ludus nagród
# sentence:  - 2.900.000,” zł,
# sentence:  3. Podróże służbowe i delegacje
# sentence:  4. Koszty biurowe/ utrzymanie
# sentence:  pomieszczeń, remonty bieżąc-
# final  pomieszczeń remonty bieżąc
# sentence:  ce i inne świadczenia /
# sentence:  4 . 200. 000,7 zł,
# sentence:  = 1.600.000,- zł,
# sentence:  5. Transport
# sentence:  150.000.” zł.
# sentence:  6. Gimnazjam św, Augustyna
# final  gimnazjami św Augustyna
# sentence:  7. Działalność społ.-polityczna
# final  Działalność socjopolityczna
# sentence:  / konierencje, kursy, zjazdy,
# final  konferencje kursy zjazdy
# sentence:  zespoły, akcje, działalność
# sentence:  zagraniczna/
# sentence:  8.240,000,- zł.
# sentence:  8. Pokrycie straty prasy i wyda”
# sentence:  : 28, 680. 000. = zł,
# sentence:  wnictw
# final  wzornictw
# sentence:  9. Podatki, opłaty
# sentence:  wam ww.
# sentence:  65 „200, 000,-zł.
# final
# sentence:  razem .
# sentence:  Budżet równoważy :
# sentence:  - wpłata z nadwyżki z całokształtu
# sentence:  = 36. 520.000, = zł,
# sentence:  działalności gospodarczej ZZG
# final  działalności gospodarczej
# sentence:  10 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig100.jpg
# final
# sentence:  IPN BU 0 639/223
# sentence:  pogłębiające się trudności wewnąirzkościelne powodują,
# final  pogłębiające się trudności wewnątrzszkolne powodują
# sentence:  pogłębiejące się trudności wewnąirzkościelne powodują,
# final  pogłębiające się trudności wewnątrzszkolne powodują
# sentence:  że coraz więcej biskupów i księży /nawet konserwotystów/
# final  że coraz więcej biskupów księży nawet konserwatystów
# sentence:  że coraz więcej biskupów i księży /nowet konserwatystów
# final  że coraz więcej biskupów księży nowe konserwatystów
# sentence:  skłania się do kontaktów z PAX-em;
# final  skłania się do kontaktów
# sentence:  kierunki zmian statutowych. Wskazywano na potrzebę:
# sentence:  nodonia wyższej rangi zespołom członkowsko-kandydackim
# final  nodoida wyższej rangi zespołom członkowskości
# sentence:  i działaniom na odcinku wewnątrzkościelnym. Zespoły
# sentence:  moją być czynnikiem integrującym Stowarzyszenie. Posie-
# final  moją być czynnikiem integrującym Stowarzyszenie prosie
# sentence:  dzenia zespołów będą miały wyższe znaczenie niż zebranic
# final  dyszenia zespołów będą miały wyższe znaczenie niż zebrani
# sentence:  Zespoły składać się będą z 10-40 osób. Kierownikami
# sentence:  będą "wartościowi politycznie" członkowie PAX. Obecnie
# sentence:  na terenie kraju działa 457 zespołów;
# sentence:  szerszego angożowania się członków PAX w działalności
# final  szerszego angobowania się członków PAX działalności
# sentence:  na rzecz Kościoła /rady parafialne, komisje, itp./;
# sentence:  rozszerzenia zainteresowania PAX-u na środowiska inteli-
# final  rozszerzenia zainteresowania na środowiska inteli
# sentence:  gencji katolickiej, duszposterstwo akademickie, studentów
# final  goecji katolickiej duszpasterstwo akademickie studentów
# sentence:  zmiany w profilu niektórych pism paxowskich - przystoso-
# final  zmiany profilu niektórych pism parowskich przystosowuj
# sentence:  wania ich do potrzeb duchowieństwa i katolików świec-
# sentence:  kich, Powstanie nowa redakcja, której celem będzie przy-
# sentence:  gotowywanie materiałów pomocniczych do pracy duszpas=
# final  gotowanie materiałów pomocniczych do pracy dusza
# sentence:  terskiej księży, artykuły zamieszczane w miesięczniku
# final  twerskiej księży artykuły zamieszczane miesięczniku
# sentence:  terskiej księży; artykuły zamieszczane w miesięczniku
# final  twerskiej księży artykuły zamieszczane miesięczniku
# sentence:  uŻycie i Myśl" mają służyć księżom i inteligencji kato-
# final  użycie Myśl mają służyć księżom inteligencji kato
# sentence:  lickiej;
# final  linckiej
# sentence:  sprawy organizacyjne. Zwrocano uwagę na:
# final  sprawy organizacyjne zwracano uwagę na
# sentence:  zenik świadomości ideowo-politycznej u niektórych
# final  zewnik świadomości ideowopolitycznej niektórych
# sentence:  członków PAX. Uwidacznia się rozkład dyscypliny orga-
# final  członków PAX Uwidacznia się rozkład dyscypliny orgia
# sentence:  nizocyjnej, źle funkcjonuje informacja, powstają zaległośc
# final  nieopcyjnej źle funkcjonuje informacja powstają zaległości
# sentence:  100 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig101.jpg
# final
# sentence:  IPN BU 0 639/223 „| ”
# sentence:  w płoceniu składek, notowane są przykłady fałszowania
# final  poceniu składek notowane są przykłady fałszowania
# sentence:  wyników pracy ogniw PAX=-u;
# final  wyników pracy ogniw
# sentence:  potrzebę większej dyscypliny i zasadności w planowaniu
# sentence:  wyjazdów zagranicznych członków Stowarzyszenia.
# sentence:  Wszystkie wyjazdy będą akceptowane przez B.Piaseckiego;
# final  Wszystkie wyjazdy będą akceptowane przez bieckiego
# sentence:  zwiększenie aktywności na zebraniach. Zebrania podsumo-
# sentence:  wywać będą mogli wyłącznie odpowiedzialni pracownicy PA
# final  wżywać będą mogli wyłącznie odpowiedzialni pracownicy PA
# sentence:  aktualne kierunki działania Stowarzyszenia:
# sentence:  z okazji XXX-lecia PRL -
# final  okazji PRL
# sentence:  - PAX zamierza podjąć akcję
# sentence:  eksponowania swego dorobku w zokresie udzielania pomocy
# final  eksponowania swego dorobku zakresie udzielania pomocy
# sentence:  Kościołowi /wystawy, wydawnictwa, spotkania z duchowień
# final  Kościołowi wystawy wydawnictwa spotkania duchownie
# sentence:  PAX zamierza wykorzystać tzw. katolickie dni społeczne
# sentence:  wyłącznie jako forum wymiany poglądów między swo imi
# final  wyłącznie jako forum wymiany poglądów między swot imię
# sentence:  członkami a młodymi księżmi;
# sentence:  w 1974 r. Stowarzyszenie zamierza rozwijać produkcję
# sentence:  dewocjonalii.
# final  dewocjonaliami
# sentence:  W trokcie obrad zatwierdzono przyjęcie 513 nowych kan-
# final  trocie obrad zatwierdzono przyjęcie nowych kan
# sentence:  dydatów. Na 11.XII.73 r, stan Stowarzyszenia wynosił 13.202
# final  dydaktyków Na stan Stowarzyszenia wynosił
# sentence:  osoby, w tym 6.158 członków i 7.044 kandydatów. Od kwietnia
# sentence:  br. Stowarzyszenie zwiększyło się o 404 osoby.
# sentence:  /Inf. Wydz. Il Dep. IV MSW
# sentence:  z dnia 14.X1.73 r. /
# final  dnia
# sentence:  101 z 348
# sentence:  ta...
# sentence:  drive/MyDrive/kuba/zdjecia/fig102.jpg
# final
# sentence:  * Krakó",dnia e». Lian sEGh23L9/3T.
# pa 3 a_j ne
# I o | i,
# . 7 ZeDLeso |
# o, 0 NACZELNIK WYDZIAŁU IV i II DEP.IV
# final  krakania Lian pa aj ne NACZELNIK WYDZIAŁU IV II
# sentence:  MILICJI Ć©'*v'y A _SKIR4/
# final  MILICJI
# sentence:  7 | ZeDTo lo
# p
# 0 NACZELNIK WYDZIA:
# final  lot NACZELNIK
# sentence:  Woj -valicowskiego
# final  Woj
# sentence:  | -gekowskiego
# Woj 1
# final  gierkowskiego Woj
# sentence:  L. dz.__
# final
# sentence:  NACZELNIK WYDZIAŁU IV i II DEP.IV
# final  NACZELNIK WYDZIAŁU IV II
# sentence:  MINISTERSTWA SPRAW WEWNĘTRZNYCH
# sentence:  WARSZAVTJIE
# final
# sentence:  awe, rkee ubueree >
# final  awen reje umbrele
# sentence:  00 /
# | LanoTY "4— ae U Oy As
# (eg 1 L 7 27 u + e
# La rL LE*4 LU
# * WARAN TNF
# final  lano ate As erg La LU WARAN
# sentence:  INFORMACJA
# sentence:  © J żę" p"
# 0 ŻiMÓG, : utworzenia przy lLiiejskim Oddziale "Pax"
# /.* - |U"w Krakowie nowego ogniwa.
# final  utworzenia przy liwijskim Oddziale Pax Uw Krakowie nowego ogniwa
# sentence:  z 8 0)
# 4? | Odi
# sentence:  w dniu 25 bm. odbyło się zorganizowane przez
# sentence:  Oddział Miejski "Pax" spotkanie przygotowawcze "Studium
# Światopoglądowego" - jak określono w zaproszeniu,
# sentence:  . jak określono w zaproszeniu,
# sentence:  | Uczestniczyło w nim 1] osób.
# sentence:  (Według wyjaśnień Bernarda Białeckiego celem spotkania
# sentence:  miało być utworzenie kilkunastoosobowej grupy - wysoko
# sentence:  a MLAGLŁU UYU ULUWULZELNIE KLLKUJASLUULSUDUWEJ BL'DY * WYBSUKO
# k* | dy ,kwalifikowanych kadr - która będzie dokonywała analizy
# UL YTY j ją Stonych dla stowarzysrenia problemów politycznych
# , y i światopoglądowych. Pracami grupy będzie kiernwał Piotr
# u A / Wwaszczenko, członek zarządu "Pax" w Warszawie, publicysta,
# d prawdopodobnie laureat nagrody Pietrzaka,
# final  dy kwalifikowanych kadr która będzie dokonywała analizy UL ją stlonych dla stowarzyszenia problemów politycznych światopoglądowych Pracami grupy będzie kierował Piotr wtaszczeniom członek zarządu Pax Warszawie publicysta prawdopodobnie laureat nagrody Pietrzaka
# sentence:  Wwaszczenko, członek zarządu "Pax" w Warszawie, publicysta,
# final  wtaszczeniom członek zarządu Pax Warszawie publicysta
# sentence:  prawdopodobnie laureat nagrody Pietrzakae
# final  prawdopodobnie laureat nagrody pierzarka
# sentence:  Przedstawiony przez niego progr"m działania :
# final  Przedstawiony przez niego program działania
# sentence:  - obliczony
# sentence:  na około półtora roku «
# sentence:  - obejmie t”kie problemy jak:
# final  obejmie tknie problemy jak
# sentence:  - światopogląd i jego rola w kształtoraniu
# final  światopogląd jego rola kształtowaniu
# sentence:  osobowości;
# sentence:  . zagadnienie styku obu światopoglądów,
# sentence:  -" zagadnienie religioznawcze i socjologii
# sentence:  reiigii,
# final  religii
# sentence:  - sprawy wewnętrzno=organizacyjne Stowarzyszenia
# final  sprawy wywnętrzaniach Stowarzyszenia
# sentence:  i sprawy jego polityki zewnętrznej,
# sentence:  Praca będzie prowadzoną metodą seminaryjną, niekiedy
# sentence:  z udziałem zaproszonych gości,
# sentence:  Według sugestii Białeckiego opracowywane temnty
# final  Według sugestii Białeckiego opracowywane tenty
# sentence:  należy przygotowywać w formie pisemnej tak by można je było
# sentence:  publikować w takich pismach jak "Kierunki","Życie i Myśl"
# final  publikować takich pismach jak kierunkujcie Myśl
# sentence:  czy "Zeszyty naukowe" Stowarzyszenia,
# sentence:  (ud 2 KCS a,
# final  ud
# sentence:  102 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig103.jpg
# final
# sentence:  ————
# sentence:  IPN BU 0 639/223
# sentence:  W trakcie dyskusji nad za.adnieniem "światopogląd
# final  trakcie dyskusji nad zagadnieniem światopogląd
# sentence:  ian totka pępacna£IDzóctogie Jaga Sfory
# final  izan totka popaczcie Jaga Sfory
# sentence:  a nauka' p.J.Dziadcsz uzupełnił zaproponowaną tematy kę
# problemem techniki propagandy i [socjologii obiegu informacji
# final  nauka pozsiadasz uzupełnił zaproponowaną tematy kę problemem techniki propagandy socjologii obiegu informacji
# sentence:  Kolejne spotkanie tej grupy zostało zapowiedziane na dzień
# sentence:  le © grudnia 19730.
# sentence:  liowopowstałe ogniwo krakowskiego Oddziału "Pax"
# final  liotropowe ogniwo krakowskiego Oddziału Pax
# sentence:  pozostawać będzie pod agenturalną kontrolą tut,iydziału,
# final  pozostawać będzie pod agenturalną kontrolą trudził
# sentence:  SYKONeW 4 egZz.i/Eg LOZdZe
# final  egzerg
# sentence:  "Ł:AŁU IV
# final  IV
# sentence:  - Wydz.Adm.KW
# final
# sentence:  ppłk gr WY,ŻYŁA
# sentence:  *Vy) |. , cze ,
# Ppłk lLigr WłŁoZIŁA
# final  cze Ppłk lir
# sentence:  = Gr.III
# final
# sentence:  103 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig104.jpg
# final
# sentence:  Warszawa, dnia 22 grudnia 1975 r.
# sentence:  :: wULJTYZKA |
# „0 211. .SKIEJ 5,0 4
# final
# sentence:  IPN BU 0 639/223
# sentence:  lajne
# final  lajnie
# sentence:  "21i.SKIEJ
# final
# sentence:  Eez.nr )
# final  eozyn
# sentence:  Misi”
# sentence:  w Wpeszawic
# final  wszawic
# sentence:  w MneszZAWwIC
# final
# sentence:  b, , (17 e e Na = >
# dz. nl |
# 138 CE — 7 "8 NACZELNIK WYDZIAŁU IV DEPARTAMEN" II
# 74 7
# Te becia OE. MINISLERSUWA SPRAW WEWNEL1RZNYCH
# m e i  - —P--——————>—>L—— R
# R s z —
# a Prema ) ,
# > dzy niniejszym przesyłam informację nr 2531/73
# dot.. niektórych zaleceń wydanych przez przewojlniczącego PAX,
# final  Na dz nul CE NACZELNIK WYDZIAŁU IV II Te becika OE SPRAW PL premia dzyń niniejszym przesyłam informację nr dot niektórych zaleceń wydanych przez przewodniczące PAX
# sentence:  NACZELNIK WYDZIAŁU IV DEPARIAMEN1 IV
# final  NACZELNIK WYDZIAŁU IV IV
# sentence:  MINISLERSUWA SPRAW WEWNELRZNYCH
# final  SPRAW
# sentence:   — z 00008
# sentence:  „do wiadomości,
# sentence:  B.FIA5ECKIEGO członkom 5towarzyszenia :
# final  członkom
# sentence:  Wykonano 2 eZze
# final  Wykonano ezie
# sentence:  egz.nr l - adresat „«
# final  egzyn adresat
# sentence:  / ppłk R. DURKAA
# final  ppłk
# sentence:  3
# wyk.J
# final  wyk
# sentence:  1”
# RW)
# A %
#
# s.
# sentence:  lęchn34 |po
# final  lękach po
# sentence:  104 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig106.jpg
# final
# sentence:  IPN „A SC
# sentence:  zd
# IPN ullóama SC
# final  zda IPN ulama SC
# sentence:  - decyzje w sprawach wyjazdów zagranicznych członków Stowarzy-
# final  decyzje sprawach wyjazdów zagranicznych członków sowarzy
# sentence:  szenia będą należeć do kierowników Oddziałów Wojewódzkich,
# sentence:  a odnośnie członków zarządu Stowarzyszenia - do przewodnt-
# final  odnośnie członków zarządu Stowarzyszenia do przewodni
# sentence:  czącego PAXŻ-u;
# final  czulącego
# sentence:  - płace w organizacji będą niższe jak w pionie prasowym;
# sentence:  - PAX jest organizacją ideowo-polityczną, wobec czego należy
# sentence:  czuwać nad utrzymaniem odpowiedniego poziomu świadomości
# sentence:  wśród członków, tym bardziej, że ostatnio u szeregu osób
# sentence:  nastąpił zanik tej świadomości,
# sentence:  Wykonano 5 e8z.
# final  Wykonano ez
# sentence:  egz.nr l - Nacz.Wydz.lV Dep.1lV MSW
# final  egzyn naszydzili MSW
# sentence:  M U 2-2 a/a
# sentence:  106 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig107.jpg
# final
# sentence:  „(+
# sentence:  „IPN BU 0638/28 - „|
# sentence:  „IPNBU Q639/228 - „|
# final
# sentence:  (3.
# sentence:  (2%
# sentence:  RENEE
# final
# sentence:  22 mo,
# 4
# -6.15 0.
# final  mox
# sentence:  -- ©
# uzmmc"ni
# final  umocni
# sentence:  JE GA
#  LUoU>= | 79
# « o. o. 2 0 a 1 (
# NSĘ y
# final  JE GA
# sentence:  Łe | lutsi.e
# final  lutnie
# sentence:  a o3306 W
# final
# sentence:  107 z 348
# sentence:  nn. [z A Z z m CC CRC CRACK
# final  non CC CRACK
# sentence:  drive/MyDrive/kuba/zdjecia/fig109.jpg
# final
# sentence:  IPN BU 0639/223 -
# sentence:  L47 Drazi8 Lu COL Li4leyczaz: ho adr
# final  drzazgi Lu COL lecza ho ar
# sentence:  AN Teta 0 naro” € Ira I: me
# 4 ru .-Z . 2 COL L0Ł1IyCZA: H dd
# final  AN theta narto Ira me ruń COL dud
# sentence:  O 13 +.
# PODAŃ Ii
# sentence:  O JSZY WYGWEPJGLIE wiQLi 02 OB LV;
# final  wii OB LV
# sentence:  «41
# sentence:  1-2
# sentence:  ZONA w L23102 Gp
# final  ZONA
# sentence:  |. -  »
# Wr tę ea ml i p” .
# — oaGŻTAC- 1 20 .OQL "4
# final  tę eza ml
# sentence:  - r 4 p
# NNS"
# final
# sentence:  ..2Zlaotw iuiatowzc.
# final  iluminatowi
# sentence:  -'2 ą ">
# 2 AC G
# sentence:  sz = 3. , 7
# cGy3 ubic .
# final  szu ubiec
# sentence:  Pono
# sentence:  m ylstitew,
# final
# sentence:  srCunlcy La.
# final  sunący La
# sentence:  srCcunlcy cu.
# final  sunący cłu
# sentence:  "ZW 1 O FZ) SJĘ 0140: 2 .
# final  ZW
# sentence:  - - „ 7. =
# X re -, .. SEL © 15 = 2 ;, " €; m! « -
# to. .. — |: — SR 02210: «„ Ę? d
# w
# final  re to SR
# sentence:  -2.a%iaj „ca
# final  ca
# sentence:  DLiCGRĘ '
# final
# sentence:  „Urysmo.ci 1a ty. oarin'n sę + „omtu.jede turicji ;
# final  ugryjskości ty oratorianin sęp omotuje triecji
# sentence:  A ndjjądzicćhw 1 ze wu iafetwwosygzy
# final  nadjedzeniach ze wu
# sentence:  Zwola wiz
# sentence:  1-1,
# sentence:  yo W GeEódyn c.uziul3 jec:
# final  yo geodyn czul je
# sentence:  -.453mu13 jec.
# ” * 1 t * 4 ata LM +. . J —
# Z = W LE YI A Ji ,
# final  je ata LM LE
# sentence:  czFconktę
# final  czcionkę
# sentence:  Ar) = 7.
# ORBASTOP NEC:
# final  Ar NEC
# sentence:  „ FvLi 7 * DS: :
# final  DS
# sentence:  DAYD DU 8 2i DO MZ: wo.
#
# " ł
# 30 a koóch | "1 rz yi "| — ,- p e 0! >
# | + O, .. |. ML. Z yMuU J = MOŻLLTd..
# | — n_j M A NA A NN NN 00
# 1.0%02 12. e L 4 | . . 9 - 4. .
# RR Li aia A 2..ZÓODW GQ. ATŻT 2 LL AA
# final  DU DO MZ wo kroch rz yin ML naj NA NN NN RR Li ażia AA
# sentence:  UL:!.
# sentence:  1-4
# sentence:  |. 0K»:90_ zslożwi, a ©
# final  zysowi
# sentence:  PRZUCUMI ŻCI1
# final
# sentence:  + 4 ,
# Poz 0 14 -, r- > -,
# ufjoileil. CI
# final  Poz uroili CI
# sentence:  „ZADC (QG.ufio li czy powyCcl s ilo
# final  li czy powyli ilom
# sentence:  „BADCCG. ufzo tu CZy przyCly nie
# final  uzo tu przyloty nie
# sentence:  ClUWAYCI
# final
# sentence:  1 .
# r PA: moc *
# CI Juiij i na
# final  PA moc CI na
# sentence:  350
# sentence:  .8 „480 powc-Eniz tazioi nbluwów Ery
# final  pocisz tiazoli noblów Ery
# sentence:  maz M ciulę
# final  mazu ciul
# sentence:  Loulalokyn:, A DDOŻPZ.
# final
# sentence:  zOulaloR;yT:; A DDOŻPL.
# final  zmulałoby
# sentence:  (a0Ł pracy wiaizn mz, lą
# final  pracy wian muz lżą
# sentence:  Z + a ZZ 4 4 2 2 ex 7 :
# 10a | VGCY Wiatlzn IMZ, LL
# 41 H L.
# final  ZZ ex wialni
# sentence:  2342 2 © 4Zi gs:
# final  gis
# sentence:  112:
# 3:12 2 © 12 a
# "SEWIE) AA
# " 4s
# final  AA
# sentence:  nie na dlor w szali roówizlu, uzyzkican e ticżycjj
# final  nie na dorn szali równiaczu uzyskiwaną triecyj
# sentence:  ” - lag LĄ. " Tę +. m” 113.2, a > c
# nie na alor w szali rowizlu, uzyzki.an e tictyc:j
# final  lag Tę nie na alo szali rozwiązuj uzyskiwaną triecyj
# sentence:  lu ozocgo ji
# final  lu ozowego jin
# sentence:  JU >:
# 9 > NEKWIEPEPE SSE
# final  JU
# sentence:  (18j1, sozzz
# final  szczysz
# sentence:  — N.ZDL: Dai2Cca
# final
# sentence:  **  m/:5 7... 7 010
#  W.EDŁI: GiZCI
# final
# sentence:  0a ». .. . m. | - - - = + | -/ > .. — -. - — = o. ad —_, c 7 NIE —+ >. = — +. s) =
# PUL - - Ć*: a" ł - GSO. =J — Pe Z. w au „' NDECL „. ALU: wet J [ — 0. = dl — ! X Z —«qd.
# . +. ". . . . a, s , O ;.....” Ś 4 4. m - 2? "4...
# . "” ZIUSETU aulu8 ZA OŻicu AL OWNTELCYWO Z gS HOL ZTAL.
# p-- » +. 2? R a moe 12 - *- KA
# PLA «. .. p, |» G T : Sr. 1 da e c 12 Sa 1] LL Q | l 3 a W ;
# . '
# final  ad NIE PUL Pe au ALU wet dl aulosu ZA AL HOL może KA Sr da
# sentence:  suelowierczwo zz gs tuou'z i.
# final  służewiecko zz gis tuz
# sentence:  -hbo pro lanów ;
# final  hubo pro lianów
# sentence:  d . p
# " © 793 -- 7. AZ *
# „ho protlamów ;
# final  AZ ho prolanów
# sentence:  LYCcA ri
# final  rui
# sentence:  załcnią kul zrv :
# final  zacenią kul zer
# sentence:  2405
# z"ią :
# ul
# TORU
# final  ziąb ul TORU
# sentence:  sa terenie Ou, zty
# "U wo”
# final  sza terenie zety wo
# sentence:  dzia, Luececią Siiz
# final  dziwa lubeckością siwizn
# sentence:  + . 4 - -
# Msi o p > da Ole
# dż e 1 PAPZAZZWE "4 U w - M
# final  da Ole dąż
# sentence:  „aDGZZI
# final
# sentence:  OjzrAńc ic o.
# final  ich
# sentence:  Misje le mlubia, a.
# final  Misje le milusia
# sentence:  zzevąni 0.. ucTzae3Ur. czy
# final  zoczeni uczerń czy
# sentence:  2-0 491g") |] -
# s LUYa:1 i e a — SEE
# - 2 1 M m2 4 ( mi: 3 LI Lzy
# »
# final  SEE mi LI
# sentence:  40 osi. LaczeLina Za.
# final  osi lacerna Za
# sentence:  ę 4. 7 ea om - p
# el oscz. naczelna Za.
# final  eza om el osącz naczelna Za
# sentence:  „lulu to: Tącenie
# final  lulu to trącenie
# sentence:  Jo stania cię
# sentence:  ożjrodkiem syelowewoczi "w Opuroju o Telszą
# final  ośrodkiem sylwetowości opoju tekszlą
# sentence:  p «
# o rodkign sStolowawo urn My - z
# , Q IGN *+ W) LO .. SV 1 w 1. m ODET e LU © " c] SPOSA
# _ aut
# final  rodzin stolcowa urn My IGN LO SV LU aut
# sentence:  Tteołę z;zlznie
# final  teł zlizanie
# sentence:  I .. 1 TI _ ie
# eg (-_CIłie
# mieełę myc
# final  TI ie erg mgiełkę myc
# sentence:  "za KPE SEA t 1 eo m — p są S$ . AR m” 2: 44. 2 ją -
#
# 4” «Qa riotyc znz:'o' Or:z pozszerzenic |wladoiorc. Gneze A1% .
# m ZDZ | m raje i ]- Tak Ź > ją 2 2 t .
# przez „© zyięuszaałj> liczcy k=nsizlatów, -raca rlubtów ma tyc
# final  za eo są AR ją roty zenzo Orz poszerzeni wodozbiorach genezie ZDZ raje Tak ją przez zwiększał liczący konsulatów raca relutów ma tycz
# sentence:  GIadOiBi Z.
# final
# sentence:  OTOLTENIEJ
# final
# sentence:  *<.
# sentence:  ovtrta ma gycozuztyczujch przle cjach,
# final  otruta ma gotycyzując prze cyjach
# sentence:  e" He ma bę 4 - A 7 1 4-1 1 4 - -
# ovtrta ma gycozuztyczujch przle cjach,
# final  He ma bęc otruta ma gotycyzując prze cyjach
# sentence:  uwzzlę nicejcy' b
# final  uwalę nicejscy
# sentence:  uleuciwa propożcje «w wytorze tzuwatów i
# final  uleciał proporcje wytworze tatów
# sentence:  "maj ) + |- oi dm o 4
# „Lla_vctiwa propożcje «w wy'orze tzuatów i
# final  maj owi dm luzactwa proporcje wyorze tatów
# sentence:  zo2cj-1ltig terzuus
# final  tezaurus
# sentence:  „lig terznu.
# zU2Cze dt
# final  lig ternu dut
# sentence:  „i lsży wyj .Orzyć ozyrmy mocal" uczeg niZUVA w DrEaEcAaCI ZliLAy
# final  lży wyj ostrzyć ozywamy mowca uczże
# sentence:  7 - a pod zyj mer 4 4] (0 ono no | wim te, a 947 m! c
# «..- lsży , K REF PZAWAJY — — i Idy BOL z] 4 > dla o wa a "a 1 ca CAC: a. ma "yy
# final  pod zżyj mer ono no wiem te lży REF Idy dla wa ca ma yyy
# sentence:  Llmig przee: „sorzamie kćr zalintr.szowań, anużowa.
# final  lig przeze szamie kuć zainteresowań anyżowa
# sentence:  z p - - - - l m » - 7 . — a a e _ 2 u
# lnia przaz; (.ovzenie kóz zainte.szcuań, Anoużowa.
# final  lnica praz ozenie kóz zapieszczań anyżowa
# sentence:  DA 0S6L 70 wyj
# final  DA wyj
# sentence:  mani» pozlatczi, 0v anicowswic
# final  mani polaczki anticolowi
# sentence:  M1l_;SCOK;
# final
# sentence:  Ml_;SĘO0n;
# w
# final
# sentence:  pojaij ot no terzwty zie
# final  pojaśnij ot no terawaty zie
# sentence:  _— - a > 4
#
# ID780A7 Me +2... 4.
#
# LJOGBO 2.2 10 Tc t m - >.
# ali id „ a LL
# final  Me Tc ali id
# sentence:  „zzane przez zt lyc. uczeostników.,s;otla!r
# final  zzuwane przez zet lycr uczestników
# sentence:  . - 4- 1 = m - " s m | "ry a > * . | ©
# czzane pzez zł tyc. uczestnikówsg3;0:AT
# final  rży czarne przez zł tycz uczestników
# sentence:  109 z 348
# sentence:  109 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig11.jpg
# final
# sentence:  IPN BU 0 639/223
# sentence:  - pokrycie straty prasy rozliczane
# sentence:  - 28 -.680, 000.7 zł,
# sentence:  w wynikach działalności ZZG
# final  wynikach działalności
# sentence:  200. 000,7 zł.
# sentence:  - wpływ ze składek członkowskich
# sentence:  65.400.000," zł.
# sentence:  razem ;
# sentence:  CHRZESCIJANSKIE STOWARZYSZENIE SPOŁECZNE
# final  STOWARZYSZENIE SPOŁECZNE
# sentence:  Realizacja budżetu za rok 1971:
# sentence:  - 7.170.000.” zł,
# sentence:  - działalność statutowa
# sentence:  »4 4 30. 000,7 zło
# sentence:  - cziałalność wydawnicza
# final  całkowalność wydawnicza
# sentence:  11.600. 000.7 Bł.
# sentence:  razem :
# sentence:  sazzuzszzązazzzzzEzzzSzzEZZnRzZNzEREZEzZZZZ
# final
# sentence:  Struktura budżetu :
# sentence:  Działalność statutowa :
# sentence:  1. Biuro Zarządu Głównego
# sentence:  = 1.580, 000, = zł.
# sentence:  dziąłaln., adm, gosp. dział fin, księg.
# final  dziąsła adm gosp dział fin księg
# sentence:  2, Sekretariat Generalny, sieć teren,
# sentence:  kontakty z duchown. Ośrod. Stuc,
# final  kontakty duchowną ośrodku sztuc
# sentence:  iDokum, Wydaw, nieperiecyczne
# final  inwokujmy wydław nieperlityczne
# sentence:  - 5,590.000,” zł,
# sentence:  "Novum", działaln, zagraniczna
# final  Novum działano zagraniczna
# sentence:  | w w mm... m www ww UW R WWW WMI
# final  mm www ww UW WWW
# sentence:  = 3%, 170,000.- zł,
# sentence:  razem ;
# sentence:  Działalność wydawnicza :
# sentence:  - 3,300.000,- zł,
# sentence:  1. Tygodnik "Za i Przeciw”
# sentence:  : 1. 130,000.- zł,
# sentence:  2, Miesięcznik "liejnał Mariacki *
# final  Miesięcznik lejna Mariacki
# sentence:  = 4.430.000.7 zł,
# sentence:  razem :
# sentence:  Budżet równoważy wpłata ChSS z nadwyżki z całokształtu
# final  Budżet równoważy wpłata nadwyżki całokształtu
# sentence:  cćziałalności gospocarczej "Ars Christiana" w wysokości :
# final  całkowalności gospodarczej Ars Christiana wysokości
# sentence:  11.600.000.” zł,
# sentence:  11 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig110.jpg
# final
# sentence:  IPN BU 0 638/223 fi
# sentence:  . = N '
# IPN BU 0 639/223 /. 2)
# sentence:  „lat niaien ju oczojkie:
# final  lat nianie ju oczkiem
# sentence:  " + © Td 3
# = la . 5 1 m "t,- 4 o szą ,
# „lat ninaien jw oczc c
# final  la szlą lat niunie jw orczyc
# sentence:  mL. trecżzy.
# final  trenczy
# sentence:  UZZUU
# final
# sentence:  + da”
# |. ..
# .OZZU ,
# final  da
# sentence:  KNEMTEE
# final
# sentence:  Dówyw
# final
# sentence:  ZZDE Z a_,óćlnej
# final  analnej
# sentence:  Za0. 3 6lnej
# final
# sentence:  10-$%0i10—:
# final
# sentence:  OEYCZ%z2: "BLADTO" 210, „la
# final  la
# sentence:  "bo ' 7 ,
# . NNaNoNKE SO , u sc 45. *
# i 4 7 Hz 2 e "M..32 0O' 2 2)... a. A
# . ' k
# final  bo SO sc Hz
# sentence:  ną ";
# ROSES
# final  nią
# sentence:  .
# NEEEAEK
# --ajaf a | malin:
# final  aja malin
# sentence:  aWwLiezy z.boż
# final  awizy zuboż
# sentence:  "Lioroli.'m, pracy-rojcinno="s"c" ŻW zj, uotulzraLyri dujsi
# final  liozoli praojcowscy ŻW zuj utulanymi dusi
# sentence:  = Y0. 2 , 1 -. Z tą — « e." m 7 1 PODTPNAEEEE da 40 za . p * - y CJ 4 .
# LO 2 100g Pracy "ro'cIl:.MO=>v. CL.Owowezzj, A Guo A ee 1: zi
# final  tą da za LO Pracy ee zui
# sentence:  215 DG66y
# final
# sentence:  p5wiig S..0rZ4iu i.i
# final  powisi ii
# sentence:  ESEE = e +. 7', rod
# Ją 125 — 02 4 „Ul L..
# final  rod Ją Ul
# sentence:  _Zmuse .
# final
# sentence:  e „POZA
# sentence:  -„ Byte.
# final  bytem
# sentence:  e Wa 2672 j;G3t UL.
# final  Wa UL
# sentence:  e Wa 2607112 jzo3t UL.
# final  Wa jot UL
# sentence:  (yYAn.8 COoctsnt
# final
# sentence:  pea 7 . LZ. ?
# u ROWK=JE . OLtEŁ
# final  peta
# sentence:  » a
# 4.012
# sentence:  jzutz
# final  juz
# sentence:  KATI SECZESZA
# final
# sentence:  "311 u: . l:
# sentence:  4177 >
# sentence:  | NODRPEZE
# 1 Ola tiM [
# final  Ola tui
# sentence:  zpoz,.
# final  zupo
# sentence:  op „22 Dutąa Z SZsj.
# final  op duta
# sentence:  „abc.' 020
# sentence:  di 02..1 1
# sentence:  h tą rr A
# „e 2 * WIOREIA
# final  tą rur
# sentence:  tzż mODty uz zvicęy z
# final  tęż męty uz zięby
# sentence:  Sa
# z owi.
# i Wa LU .
# Łob Z69t;
# final  owi Wa LU
# sentence:  GADLI.L
# final
# sentence:  SSZESK .
# 101.. _
# final
# sentence:  łor OBUrEvai
# final
# sentence:  i - ESR "
# 4 r p * r
# © Onurzsan..
# final  orzyszan
# sentence:  - m „reżi Vucrzaj 0008 15o.iow'
# final  reżim
# sentence:  . 4 2;
# ] "atrza” 0508 150.10.
# m „reji "iczrza” ov0g z
# final  atrezja rejki izolarza
# sentence:  r .
#
# JEJNENIEJE
#
# w | -
# * -
# final
# sentence:  NE
# -- a DLYDSE)
# final  NE
# sentence:  "LorLa',
# final  lora
# sentence:  7 py 241
# GUL 0
# final  pyś GUL
# sentence:  2 „alli
# final  allil
# sentence:  00 madlyzą w 6 „.C.6LL
# final  mdlą
# sentence:  Lo8 3 ZA.
# final  ZA
# sentence:  SODERONEKZE
# — — 9
# final
# sentence:  7 -.3Ey
# final
# sentence:  2020.
# sentence:  2023
# LL
# LLL.
# final
# sentence:  . QS0ż"
# final
# sentence:  NADSACZEGE
# final
# sentence:  ty r7 70%
# ' — taż.
# final  ty taż
# sentence:  *-
# Pee 12
# final
# sentence:  OWIMIW
# final
# sentence:  -c-gol' i"
# final  col
# sentence:  2c-gol' Pok
# final  Pok
# sentence:  201, 50, 67
# A „l
# sentence:  2 5 Za Glin a 1 cb.o-poló ct: zz
# final  Za Glin cool cyt zz
# sentence:  - - m ma = 7 h - - 2a -
# 2 0 Za Glin s 1 GD.o=polit:czz
# L
# final  ma Za Glin geopolityczną
# sentence:  OrpCZLIG 38 0 ct
# final  cyt
# sentence:  T .
# gej ga A b „- a fo
# olpeżla j8 0_ 02
# final  gej gza fot opiela
# sentence:  IBASECE
# final
# sentence:  Ir "
# NESSRTS
# RS
# o
# final  Ir
# sentence:  Za0A6: polczi j
# final  policzki
# sentence:  BESSA
# sentence:  1.6 "GULI OGU, U
# final  GULI
# sentence:  Z£EZCILILIORŚRZ GODEJ
# final
# sentence:  "ao" m. -
# Z8ELTPLOBRKHZ GDEW Z
# final  ao
# sentence:  UZCOLTESTZ
# final
# sentence:  | 1, >
# UZCOLTESTZ
# final
# sentence:  p 1 s "Taa. a za
# final  za
# sentence:  LZX06%5 11 GL ,
# final  GL
# sentence:  karze
# sentence:  «4 mo”
# final  mox
# sentence:  uJZLEiZ
# final
# sentence:  Zyd...
# final
# sentence:  WART 'Y
# z << 1d... .
# w
# final  WART
# sentence:  - , 10C15TPA4..
# final
# sentence:  ESEE OENSEES Pr —
# „1 u c — AT KZ — 1. di c
# final  Pr AT di
# sentence:  ZPOZAGOT
# final
# sentence:  i O: (1.1
# Na 1..
# sentence:  a _DODEBILO .
# final
# sentence:  m___DEGBILO
# m a | NKK | | MA
# final  MA
# sentence:  -- +-—
# sentence:  e ..2a
# final
# sentence:  YŻe--. 4/0!
# final
# sentence:  —
# " o7TJó .
# final
# sentence:  "12 ,
# 7 +>©B =
# sentence:  GZOUCą do JUŻ .G
# final  do JUŻ
# sentence:  NETENECEN
# final
# sentence:  ""'zr a s
# a A Ć 9 =lL
# final  zer
# sentence:  110 z 348
# sentence:  ———_
# sentence:  drive/MyDrive/kuba/zdjecia/fig111.jpg
# final
# sentence:  SATonii.
# final
# sentence:  . !
# Łącz i
# u 777 pz
# sentence:  p 7 - 2 - ma Bu-dóżoczi :1.7 "M
# final  ma budżetowcze
# sentence:  -n 02-233 _pyBudózwzeg 13 Ą
# S+ w_Llitr U A
# final  wistr
# sentence:  pazizec 1 Paco. ©L. 1U..CACI A
# final  pazie Paco
# sentence:  * "" li. IE KNEW PE +” "1
# a dsżiba.4/51 2 LL a (LL... lu... vżuil A
# M m ma 0
# final  li IE PE dysażia lu ma
# sentence:  M U. 1%:..% w
# sentence:  SERYZER i.
# final
# sentence:  "LTCLU oubyła s1$ « «niu 9.1,1374 r, v.avic=
# final  obyła niżu
# sentence:  "LTCLU Ooubyła się w «nin 9.1.,1574 r, u.acic=
# final  obyła się ni uciec
# sentence:  LO GLiLŁłAlIiOsSC
# final  LO
# sentence:  -<yeziału u/s iuicjuty, itrerno.ych
# final  us inicjujmy internowanych
# sentence:  <"yeziału 4/5 ililcjuty,. itrero.ych
# final  inicjujmy iterowanych
# sentence:  orcz zezaczienie cziałeliosci raunych z rawie-
# final  oracz zacienie czeliści rżanych rawie
# sentence:  orcz zejaczierie uziatiliosci rcunych z raswie=
# final  oracz zacierpie uzdatniliście runnych rasowie
# sentence:  nia Paa, dcieraty wygłosili: Jerzy Lis -p.o. tie
# final  niwa docierały wygłosili Jerzy Lis po tie
# sentence:  nia Paa, „deleraty wygłosili: Jerzy Lis -p,o. :ie
# final  niwa delegaty wygłosili Jerzy Lis po ie
# sentence:  rovniza „yaziilu G/s Iricjzty« oraz „enryk: fale
# final  rolnicza Gs oraz ery fale
# sentence:  rovniza „yaziiłu G/s Inicjatyw oraz „enryk fala
# ant 222.1 .
# final  rolnicza Gs Inicjatyw oraz ery fala ant
# sentence:  NB iż 00, zaażch. a ysjabji za
# final  NB iż zapach za
# sentence:  - ego mL
# wf, rei - „oorcynator pracy raauych, w uyszusji za-
# „rali „łos wszyscy irze.odnuiczęcy Ouażiałów wo=
# final  ego wf rei ordynator pracy rusych uzusie za rwali wszyscy ironiczny odważniaków wo
# sentence:  -„00Tcynator pracy radnych, u cysiusji za
# final  pracy radnych cycusi za
# sentence:  „00rcynator pracy radnych. w Cdysiusji za-
# final  pracy radnych za
# sentence:  jesóczzich, Pol suuouania narady uoxonał yszard
# final  jesziwach Pol sumowania narady ułożona yard
# sentence:  , > , , -. - - s -— w  — m m | dh w * us
# WOGZILI GOW GUY 0: IvSze
# Jevoczzich. Pocsuuowenia narcuy uoxoiał :iyszard
# final  duh us jednoczeniach posowienia narcyz udomowiał irysa
# sentence:  aciff '
# final  acie
# sentence:  - członek lrezytciun ZG PAX,
# final  członek leczycie PAX
# sentence:  (oauwiając wytyczne ao pracy Odcziałów uoje-
# final  omawiając wytyczne ao pracy oddziałów upoje
# sentence:  (vaewiając dytyczne Go pracy Odcziałów uoje-
# final  dotyczne Go pracy oddziałów upoje
# sentence:  Lódzuien, pochreślano M.in,, że:
# final  lądzieni pochlano Min że
# sentence:  <«0dzxieh, pochreślano u.in,, że:
# final  pochlano uwinę że
# sentence:   „rzygotowania Piza Go obcnhoców RMci-lecia PAL
# final  rozgotowania Piza Go obchodów PAL
# sentence:   „rzygotowania Pi:a ao obcnowów M_CLi-lecia PAL
# final  rozgotowania Pia ao odchowów PAL
# sentence:  rozpoczną się po styczniowy:: Plenun „U na
# final  rozpoczną się po styczniowy plenum na
# sentence:  rozpoczną słę po styczniowy: Plenum U na
# final  rozpoczną słęp po styczniowy Plenum na
# sentence:  ten teuiat, „ oparciu o Uciwauł ż Ko, Pax opra-
# final  ten teurgia oparciu ukochiwał Ko Pax oprań
# sentence:  teu teuat., „ oparciu o Uciwałz KC, PAX opra-
# final  texu tenut oparciu ukochiwał KC PAX oprań
# sentence:  cuje plan, itóry bęczie oziówi ony LU spcejal=
# final  czuje plan itry będzie ozimówki orny LU specjale
# sentence:  cuje plan, itóry byczie owsówiony nu specjal-
# final  czuje plan itry byczcie omówiony nu specjale
# sentence:  nym posieczeniu Zurząacu Głównego;
# final  ny posieczeniu Głównego
# sentence:  'v zakresie iniejaty, tercnovych cziełalnosc
# final  zakresie inicjatyw tercynowych czesalnio
# sentence:  "w zakresie inicejaty, tercnovych cziełslnosc
# final  zakresie inicjatyw tercynowych czesalnio
# sentence:  Vaz cinsa konecitrować siy zlównie wol:ół
# final  cisa kontrować siły zlewnie wolał
# sentence:  "aa vinsa konecztrować siy zlównie uo!:ół
# final  aa kontrować siły zlewnie usmoł
# sentence:  problemów?
# sentence:  „walki z alzonoliziz.em; opieki nać nłoczie=
# final  walki alkoholizie opieki nać nocie
# sentence:  . walki z alzonoliziiem; opieki nać ułodzie=
# final  walki alkoholizie opieki nać ułudzie
# sentence:  żą trudną,przy współpracy z oćpowieunini
# final  trudną współpracy opromienieni
# sentence:  żą trudną,przy współpracy z ocpowieunimi
# final  trudną współpracy odpowiednimi
# sentence:  „0uisjani PJ i kosi tetaiai blokowytni;
# final  kosi tetaniami blokowni
# sentence:  „ouisjadwi FJ» i kocwitetani blokowymi;
# final  osadowi kwietni blokowymi
# sentence:  poraunictwe ro.zinnezo przy czyni:ej u:pół=
# final  poradnictwie rodzinnego przy czynniej uplótł
# sentence:  poraunictue rocziniezo przy czyniuiej w: pół=
# final  poradnictwu rocznie przy czynniej pół
# sentence:  Drucy z usiężmi;
# final  ducy ujskimi
# sentence:  . rozsyijania precy kulturalicj poprzez
# final  rozsypiania przeczy kulturalniej poprzez
# sentence:  « rozzijanie precy kulturaliej poprzez
# final  rozwijanie przeczy kulturalniej poprzez
# sentence:  śluby terenowe b.X, ueeniovo, ŻE „otych
# final  śluby terenowe uderzeniowo ŻE ozutych
# sentence:  gluby terenowe PX, uceniovo, że uotych-
# final  gzuby terenowe uczerniono że ulotnych
# sentence:  czesoną Guzieglzinosć „„lubów cechuje bcz=
# final  czesaną luzów cechuje bycz
# sentence:  czesoną Gzielcinosć lubów cechuje bcz=
# final  czesaną gnieciono luzów cechuje bycz
# sentence:  płodnowe i chaotycznore, fe:atyka oiczy-
# final  płodowe chaotyczne fonematyka oczy
# sentence:  płodnosć i chaotyczność, tc:atylka oGczy-
# + 2 _- r. " . - - |
# final  płodność chaotyczność tatynka oczy
# sentence:  tów w 5Ulubach winne byc zucngażowana
# final  tyłów winne bycz zaangażowana
# sentence:  > - z — - —  . =" w — "w a
# r" 4 !. , = -- 4 + m. 1- -- n . ". - x
# ŁO DU zludonch "Liv JYC GUCNZCZOWANA
# final  DU zaludnionych
# sentence:  1 zzocna z linia polityczną PAX;
# final  zona linia polityczną PAX
# sentence:  1 zzocna z linia polityczną PAŃ;
# final  zona linia polityczną PAŃ
# sentence:  111 z 348
# sentence:  nN—et141,Q0(( (VX0OC__
# final
# sentence:  drive/MyDrive/kuba/zdjecia/fig112.jpg
# final
# sentence:  IPN BU 0 639/223,
# sentence:  ".0mieclrz Jizty uruyzynienie ezizledliosua zcz
# final  uszynienie eidosu zocz
# sentence:  , R a 2 > - mk Le. 0 4  $ 4.7, , : - .- o
# : --O..16G0C.1. - LLL u .L$ 1 LEI: LO 717 1-1 NORSE _c z
# final  mąk Le LEI LO
# sentence:  28 © ty:-+ Celu:
# sentence:  28 © ty: CelU3:
# final  ty
# sentence:  12..10
# sentence:  — 7 e
# .312..10
# sentence:  . "YLZ1GŁ trzganiziceyjny P.a ojrccuje
# final  transpozycyjny Pa ojcuje
# sentence:  specjali.e tezy jIo.bveuicze Guo ulkierun:0—
# final  specjalnie tezy joniczne ukierunkuj
# sentence:  wania rucieżo i je.o pracy „ radach,
# final  wania ruńcież jeon pracy radach
# sentence:  iczy zozżtaią rozesłurne u0 -«szyst:ich
# final  imaczy zostawią rozesłane szytych
# sentence:  cuuzżiełów;
# final  czimetów
# sentence:  LULZ ]
# ziełów;
# ,
# final  ziłów
# sentence:  „ Go Lonca zarca br, we uszyst:ich Luuzia-
# final  Go lotnica zżarcia br we uszytych ludzika
# sentence:   Łłech „ojewóuzi:ich Pak tuają dyć zorzceni-
# final  owadzich Pak tułają dyć zrzuceni
# sentence:  z0.6ciie specjalne zcbrania pos.ięcone
# final  złocicie specjalne zebrania posmęcone
# sentence:  brecy reunych, szcze.óliuie w racuch giuin-
# final  brechy runnych szczeliwie racuch gin
# sentence:  iych,
# final  ich
# sentence:  /Inf, wydz.!II Ven,IV
# final  Inf wydze
# sentence:  Z ania 12,1,13974 r./
# final  anima
# sentence:  112 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig113.jpg
# final
# sentence:  Załącznik do zestawu. ważniejszych p”
# sentence:  Załącznik do zestawu ważniejszych |y-
# sentence:  informacji z dnio Śgy bę lygaś:253
# final  informacji dynio bęc
# sentence:  SPOTKANIE RED.CZAJKOWSKIEGO Z PAX Z KSIEŹŻMI
# final  SPOTKANIE PAX
# sentence:  I AKTYWEM KATOLICKIM W KATOWICACH
# sentence:  Stowarzyszenie Pax zorganizowało w Katowicach spotkanie
# sentence:  rzymskiego korespondenta Pax - redaktora Czajkowskiego
# sentence:  o ae akiec ow Watycanie, na temat wizyty Ministra
# final  ate akie ową wytyczanie na temat wizyty Ministra
# sentence:  z księżmi i działaczami świeckimi na temat wizyty Ministra
# sz) Ol szowskiego w Watykanie.
# final  księżmi działaczami świeckimi na temat wizyty Ministra szu Ol szumowskiego Watykanie
# sentence:  Wzięli udział: A.Roztworowski - zajmujący się w Paxie współ-
# final  Wzięli udział antykorowski zajmujący się Paxie wespół
# sentence:  pracą z duchowieństwem, przewodniczący Oddziału Wojewódz-
# final  pracą duchowieństwem przewodniczący Oddziału województw
# sentence:  J.Waleczek, członkowie Sekretariatu OW
# final  jameczek członkowie Sekretariatu
# sentence:  kiego w Katowicach -
# sentence:  i ok. 90 osób w tym ok.50 księży z diec, krakowskiej, często-
# final  ok osób tym ok księży diec krakowskiej często
# sentence:  chowskiej i katowickiej oroz 2 pastorów kościoła luterańskiego
# final  czchowskiej katowickiej orz pastorów kościoła luterańskiego
# sentence:  z Zabrza i Bytomia,
# sentence:  Redaktor Czajkowski omówił problem wizyty Min. Olszows-
# final  Redaktor Czajkowski omówił problem wizyty Min olszową
# sentence:  kiego z punktu widzenia: stosunku Watykanu do Polski w okresie
# sentence:  powojennym, politycznego charakteru wizyty , reakcji prasy
# sentence:  włoskiej i światowej oraz ze strony kół rewizjonistycznych i kon-
# final  włoskiej światowej oraz ze strony kół rewizjonistycznych kron
# sentence:  serwatywnych na Zachodzie. Powiedział m.in., że:
# final  sedatywnych na Zachodzie Powiedział min że
# sentence:  stosunek Jana XXIII i Pawła VI był zawsze i jest serdeczny.
# final  stosunek Jana Pawła VI był zawsze jest serdeczny
# sentence:  Swiadczą o tym: uznanie w 1962 r. przez Jana XXIII
# final  sąsiadeczką tym uznanie przez Jana
# sentence:  polskich ziem zachodnich i północnych; ustanowienie
# sentence:  przez Pawła VI polskiej administracji kościelnej na tych
# sentence:  ziemiach; likwidacja ambasady rządu londyńskiego przy
# sentence:  Watykanie i odmówienie akredytacji Papee; rozmowy
# final  Watykanie odmówienie akredytacji pele rozmowy
# sentence:  podjęte z Polską; nominacja kard. Kominka; spotkanie
# sentence:  Min.Olszowskiego z arcbepm Cosaroli w Helsinkach,
# final  mniszkowskiego arabem corolli Helsinkach
# sentence:  podczas którego uzgodniono wspólne działania Polski
# sentence:  i Watykane na rzecz pokoju oraz wyrażono chęć normali-
# final  wtykane na rzecz pokoju oraz wyrażono chęć normalsi
# sentence:  zacji stosunków Polska-Watykan. Red. Czajkowski uważa,
# final  zacni stosunków poskakano Red Czajkowski uważa
# sentence:  że na przełomie 1973/74 roku Polska znalazła się w orbi-
# sentence:  cie wpływu polityki watykańskiej;
# sentence:  113 z 348
# sentence:  drive/MyDrive/kuba/zdjecia/fig114.jpg
# final
# sentence:  IPN BU 0 639/223 (l. , N |
# sentence:  «| N o
# IPN BU 0 639/223 [le 4-5
# sentence:  wizyta Min. Olszowskiego w Watykanie przebiegała
# sentence:  w atmosferze szukania punktu zbliżenia i unikania spraw
# sentence:  mogących doprowadzić do zadrażnień stosunków między
# sentence:  Polską a Watykanem. Papież wyraził szacunek dlo kraju
# final  Polską Watykanem Papież wyraził szacunek dolo kraju
# sentence:  socjalistycznego i jego polityki, używając słów partia.
# sentence:  i Polska Rzeczpospolita Ludowa; Min. Olszowski wyraził
# sentence:  uznanie dla polityki pojednania i pokoju Watykanu
# sentence:  i osobistego wkładu papieża oraz z szacunkiem mówił,
# sentence:  że katolicy w Polsce wspólnie budują socjalizm;
# sentence:  konsekwencją wizyty Min. Olszowskiego w Watykanie
# sentence:  będą dalsze rozmowy między Polską a Watykanem
# sentence:  /zaproszenie i przyjazd arcbpa Casaroli do Polski/,
# final  zaproszenie przyjazd arba Casaroli do Polski
# sentence:  które rokują nadzieje na osiągnięcie porozumień na
# sentence:  bazie poszanowania: Konstytucji i przepisów prowa przez
# final  bazie poszanowania Konstytucji przepisów parowa przez
# sentence:  Kościół, a wolności religijnej przez Państwo;
# sentence:  prasa włoska i światowa wytworzyła odpowiedni klimat
# sentence:  do rozmów Polska-Watykan, którego nie mogły zakłócić
# final  do rozmów poskakano którego nie mogły zakłócić
# sentence:  nawet koła rewizjonistów i konserwatystów. Zarzucały one
# sentence:  papieżowi, że czyni zbyt wiele gestów pod adresem komu-
# sentence:  nistów, rozbestwia ich, psuje posoborową atmosferę
# final  nitów rozbestwia ich psuje posoborową atmosferę
# sentence:  w Kościele, potęguje kryzys. Atmosfera ta wytrąciła
# sentence:  argumenty o Kościele cierpiącym i milczącym kolportowa-
# final  argumenty Kościele cierpiącym milczącym kolportowań
# sentence:  ne na Zachodzie przez niektórych hierarchów polskich.
# sentence:  Zdaniem red. Czajkowskiego w Polsce istnieją,warunki do
# final  Zdaniem red Czajkowskiego Polsce istniejąca do
# sentence:  normalizacji stosunków Państwo-Kościół. Widzi to papież
# final  normalizacji stosunków państwowości Widzi to papież
# sentence:  i Watykan. Polska dotychczas była wyspą w Kościele, którą
# sentence:  omijały negatywne zjawiska kontestacji i obojętności religijnej.
# sentence:  Papież dąży do podpisania z władzami polskimi porozumień
# sentence:  gdyż jest przekonany, że te prądy dotrą również do Polski.
# sentence:  114z 348
# final
# sentence:  drive/MyDrive/kuba/zdjecia/fig115.jpg
# final
# sentence:  q
# IPN BU 0 639/223:
# sentence:  Chce on ochronić Kościół przed wstrząsami jakie mają miejsce
# sentence:  w innych krajach,
# sentence:  W dyskusji zabrało głos 6 osób, w tym 4 księży. Intereso-
# final  dyskusji zabrało głos osób tym księży interesom
# sentence:  wano się: ewentualnym przyjazdem papieża do Polski; stanowis-
# final  wlano się ewentualnym przyjazdem papieża do Polski stanowisz
# sentence:  kiem Episkopatu polskiego do rozmów Polska-Watykan i norma-
# final  kitem Episkopatu polskiego do rozmów poskakano norma
# sentence:  lizacji stosunków Państwo-Kościół ; rolą biskupa Dąbrowskiego
# final  logizacji stosunków państwowości rolą biskupa Dąbrowskiego
# sentence:  w Watykanie w czosie pobytu Ministra; problemem administracji
# final  Watykanie czikosie pobytu Ministra problemem administracji
# sentence:  Bi" Pieczzjech wschodnich, ano aka oe
# final  Bi pieczeniach wschodnich ano aka owe
# sentence:  = kościelnej w diecezjach wschodnich; stanowiskiem działaczy
# - 4. te le 1 - o mtfe_ | ee 102 le. — Vu
# final  kościelnej diecezjach wschodnich stanowiskiem działaczy te le myte ee le
# sentence:  stowarzyszeń katolickich wobec normalizacji stosunków z Kościo-
# final  stowarzyszeń katolickich wobec normalizacji stosunków kościom
# sentence:  łem. Jeden z księży krakowskich poruszył sprawę trudności Koś-
# final  Jeden księży krakowskich poruszył sprawę trudności Koś
# sentence:  cioła w Polsce, twierdząc że Kościół jest szykanowany przez
# final  ciołka Polsce twierdząc że Kościół jest szykanowany przez
# sentence:  władze terenowe.
# sentence:  Odpowiedzi udzielił red, Czajkowski. Podkreślił, że
# sentence:  Episkopot nie reprezentuje ani Państwa, ani całości katolików
# final  episkopom nie reprezentuje ani Państwa ani całości katolików
# sentence:  w Polsce. W sprawie porozumień Polska-Watykan może mieć
# final  Polsce sprawie porozumień poskakano może mieć
# sentence:  tylko głos doradczy. Polska nie może występować do Watykanu
# sentence:  o rozwiązanie problemu administracji kościelnej w diecezjach
# sentence:  wschodnich, jeśli tego nie czyni Związek Radziecki. Zaakcen-
# final  wschodnich jeśli tego nie czyni Związek Radziecki zaakcentuj
# sentence:  towoł, że działalność kard. Slipyja, który podburza nacjonalistów
# final  towot że działalność kard slipy który podburza nacjonalistów
# sentence:  ukraińskich, stanowi prowokację wobec Watykanu i Związku
# sentence:  Radzieckiego. Red. Czajkowski stwierdził, że sytuacja Pax w Wc
# final  Radzieckiego Red Czajkowski stwierdził że sytuacja Pax
# sentence:  tykanie uległa znacznej poprawie.
# sentence:  Po części oficjalnej odbyło się sute przyjęcie dla uczest-
# final  Po części oficjalnej odbyło się sute przyjęcie dla uczesz
# sentence:  ników spotkania,
# final  niklów spotkania
# sentence:  /lnf. Wydz. II Dep. [M MSW
# z dnia 23.1.74 W,
# final  lun Wydz II Dep MSW dnia
# sentence:  115 z 348
# sentence:  ——————
# sentence:  drive/MyDrive/kuba/zdjecia/fig116.jpg
# final
# sentence:  IPN BU 0 639/223
# sentence:  |. de”. . " a)
# RENNOSRSSKNE , DE! 1 bola
# , : - _
# final  de DE bola
# sentence:  4_)
# final
# sentence:  > '8 al" ....
# sentence:  dot. posieuzciia „meedlu Stow, rm w dniu ŻA.I. 574 r
# final  dot posiedział menelu stołów rym dniu
# sentence:  mona pa dyGzuda AUWJĄ W. twenyto gl u
# final  mona pa dyza tiento gól
# sentence:  NADA o UGT By I po Pate Pamodjajasmeta OD D; e
# final  NADA By po pater OD
# sentence:  *'|  —
# sentence:  aż SZCZ, AzOWO OLI AH 3. Na ,
# final  aż OLI Na
# sentence:  "E , po , a." ., * IEESZ da = ho = „es . 17 * 7 '
# „ł.'1 OW 11 0 5 AwiOWO= OLI w lc, „|. I ,
# final  po da ho es OLI ląc
# sentence:  podżueott ni OWRL uQaoiwic Wa: luuec,1.,
# final  podżegło ni uazowi Wa luzujecie
# sentence:  hak) RM
# padej zatr ae tory j a) |
# , i Gb 1) „0400
# Po wDadiióch 1:1 |
# w |. ' ma u
# e: |. AGC
# final  hak RM pajdej zatrę ate tory Gb Po wadiach ma
# sentence:  d4 rGreDaCiEe pas ii O80ZL Wyenó win Kopia MJ TE
# final  pas ii wycen win Kopia MJ TE
# sentence:  problenyż
# final  problemy
# sentence:  "Pa" 1h 11075
# a Ol l WI
# final  Pa Ol WI
# sentence:  1, PeC DRY aoyctyczzą (SB
# final  DRY aorystyczną SB
# sentence:  "4 ż *_ a 2” - -,”. 1, , ro. "Ron Z c =
# 1. ech, oiewe" eny tyczną
# final  ro Ron ech owiewek eony tyczną
# sentence:  arnfz Tia”!
# final  arf
# sentence:  - NEDIRINENNKSE
# "14! BU
# u
# final  BU
# sentence:  Stona: actywvnonc Ao DCZENIA GAS. aósdh lo cwia nii
# final  sztona aktynon Ao asdicach lot cywila
# sentence:  4; z . m1. 41 >
# STO REREENIE 2 .
# . -' u tl 2 (_ 1. NC ,ł 4 4 oa,, * +. 1 6a" 1 U ;
# RE ea p) 4 7 = ; IKM) "U li: | >
# final  STO tul owa RE eza li
# sentence:  m uytuary, una PTE"! u. Li, o; pat Ue. oe” 1, ny. 4
# final  utarły una PTE Li pat owe ny
# sentence:  e ., , . . . DO . ,
# ucrknNio : aa PP” my ( Po Ą: 26050] 7 u: MIONDNNNANSSSZES 1" oe
# mocyjtnony, udp eTe na kie ód po IE
# final  DO uranio aa PP my Po owe udup ee na kie ód po IE
# sentence:  1% "ónnia:" OTG ir: poli, naererwiekhma geek re

# %%
#np.save('drive/MyDrive/kuba/zapis_numpy.csv',np.array(correct))
