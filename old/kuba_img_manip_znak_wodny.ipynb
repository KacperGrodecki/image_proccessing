# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperGrodecki/image_proccessing/blob/main/kuba_img_manip_znak_wodny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install poppler-utils 
# !apt-get install tesseract-ocr-pol
# !apt-get install libleptonica-dev 
# !apt-get install tesseract-ocr
# !apt-get install tesseract-ocr-dev
# !apt-get install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (239 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
# ...

# %%
pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=d8f59854180a18779cf653889a9fc793f7ccc7462fb0d75af10e1fcdb7785a5f
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
from PIL import Image 
import pytesseract 
import sys 
import os
import pandas as pd
import cv2 
import os
from PIL import Image
from pytesseract import image_to_string
import numpy as np
from matplotlib import pyplot as plt
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from matplotlib.pyplot import figure

# %%
from skimage import io
import matplotlib.pyplot as plt
image = io.imread('drive/MyDrive/kuba/fig1.jpg')

# %%
image = io.imread('drive/MyDrive/kuba/fig1.jpg')
#_ = plt.hist(image.ravel(), bins = 256, color = 'orange', )
_ = plt.hist(image[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
_ = plt.hist(image[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
_ = plt.hist(image[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])
plt.ylim(0,100000)
plt.show()

# %%
image = io.imread('drive/MyDrive/kuba/fig53.jpg')
#_ = plt.hist(image.ravel(), bins = 256, color = 'orange', )
_ = plt.hist(image[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
_ = plt.hist(image[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
_ = plt.hist(image[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])
plt.ylim(0,100000)
plt.show()

# %%
image = io.imread('drive/MyDrive/kuba/fig10.jpg')
#_ = plt.hist(image.ravel(), bins = 256, color = 'orange', )
_ = plt.hist(image[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
_ = plt.hist(image[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
_ = plt.hist(image[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])
plt.ylim(0,100000)
plt.show()

# %%
rgb_image = io.imread('drive/MyDrive/kuba/fig10.jpg')

# %%
blue_image = rgb_image.copy() # Make a copy
blue_image[:,:,1] = 0
blue_image[:,:,0] = 0

# %%
#green_image[green_image[:,:,2]>130]=250 maska

# %%
blue_image_copy = blue_image.copy() # Make a copy

# %%
blue_image[10:20,10:20,2].mean()
# Out:
# 76.91

# %%
for i in range(0,blue_image.shape[0]-15):
  for j in range(0,blue_image.shape[0]-15):
    figure_mean=blue_image[i:i+30,j:j+30,2].mean()
    #print(figure_mean)
    if figure_mean>130 and figure_mean<150:
     # print('true')
      blue_image_copy[i,j,2]=200
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: Mean of empty slice.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
i=0
for x in np.nditer(blue_image[:,:,2], order='F'):
  figure_mean=blue_image.mean()

# %%
plt.figure(figsize=(15,15))
plt.imshow(blue_image)

# %%
plt.figure(figsize=(15,15))
plt.imshow(blue_image_copy)
